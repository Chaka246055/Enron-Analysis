# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaka246055/Enron-Analysis/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('elp_sales.csv')

print(df)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
region_df = df[['Region', 'Total Profit']].copy()
print(region_df)
# Out:
#                                Region  Total Profit
# 0               Australia and Oceania     951410.50
# 1   Central America and the Caribbean     248406.36
# 2                              Europe     224598.75
# 3                  Sub-Saharan Africa      19525.82
# 4                  Sub-Saharan Africa     639077.50
# ..                                ...           ...
# 95                 Sub-Saharan Africa      65214.72
# 96                               Asia      15103.47
# 97                 Sub-Saharan Africa      93748.05
# 98                      North America     144521.02
# 99                 Sub-Saharan Africa     889472.91
#
# [100 rows x 2 columns]

# %%
df.loc[df['Region'] == 'Australia and Oceania']
# Out:
#                    Region                         Country        Item Type  \
# 0   Australia and Oceania                          Tuvalu        Baby Food
# 5   Australia and Oceania                 Solomon Islands        Baby Food
# 19  Australia and Oceania                      East Timor             Meat
# 23  Australia and Oceania                     New Zealand           Fruits
# 26  Australia and Oceania                        Kiribati           Fruits
# 32  Australia and Oceania                       Australia  Office Supplies
# 56  Australia and Oceania                            Fiji          Clothes
# 60  Australia and Oceania                       Australia           Cereal
# 76  Australia and Oceania  Federated States of Micronesia        Beverages
# 79  Australia and Oceania                          Samoa         Cosmetics
# 91  Australia and Oceania                       Australia        Beverages
#
# ...

# %%
australia_df.sort_values(['Country', 'Total Profit'], ascending=True)
# Out:
#                    Region                         Country        Item Type  \
# 60  Australia and Oceania                       Australia           Cereal
# 91  Australia and Oceania                       Australia        Beverages
# 32  Australia and Oceania                       Australia  Office Supplies
# 19  Australia and Oceania                      East Timor             Meat
# 76  Australia and Oceania  Federated States of Micronesia        Beverages
# 56  Australia and Oceania                            Fiji          Clothes
# 26  Australia and Oceania                        Kiribati           Fruits
# 23  Australia and Oceania                     New Zealand           Fruits
# 79  Australia and Oceania                          Samoa         Cosmetics
# 5   Australia and Oceania                 Solomon Islands        Baby Food
# 0   Australia and Oceania                          Tuvalu        Baby Food
#
# ...

# %%
australia_df.sort_values(['Country', 'Total Profit'], ascending=False)
# Out:
#                    Region                         Country        Item Type  \
# 0   Australia and Oceania                          Tuvalu        Baby Food
# 5   Australia and Oceania                 Solomon Islands        Baby Food
# 79  Australia and Oceania                          Samoa         Cosmetics
# 23  Australia and Oceania                     New Zealand           Fruits
# 26  Australia and Oceania                        Kiribati           Fruits
# 56  Australia and Oceania                            Fiji          Clothes
# 76  Australia and Oceania  Federated States of Micronesia        Beverages
# 19  Australia and Oceania                      East Timor             Meat
# 32  Australia and Oceania                       Australia  Office Supplies
# 91  Australia and Oceania                       Australia        Beverages
# 60  Australia and Oceania                       Australia           Cereal
#
# ...

# %%
australia_df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.100000e+01    11.000000   11.000000   11.000000   1.100000e+01
# mean   4.012882e+08  6211.363636  222.672727  154.744545   1.281297e+06
# std    2.059484e+08  3580.884256  209.060366  168.067124   1.348356e+06
# min    1.422784e+08   682.000000    9.330000    6.920000   2.040471e+04
# 25%    2.288457e+08  2949.000000   47.450000   31.790000   2.926605e+05
# 50%    3.471403e+08  5908.000000  205.700000  117.110000   7.592027e+05
# 75%    5.979361e+08  9521.500000  338.585000  211.375000   2.198332e+06
# max    6.708547e+08  9925.000000  651.210000  524.960000   4.220729e+06
#
#          Total Cost  Total Profit
# count  1.100000e+01  1.100000e+01
# mean   8.520096e+05  4.292873e+05
# std    9.228386e+05  5.102405e+05
# min    1.513404e+04  5.270670e+03
# 25%    1.890137e+05  1.036468e+05
# 50%    3.549952e+05  2.850876e+05
# 75%    1.558613e+06  5.482891e+05
# max    2.542188e+06  1.678541e+06

# %%
print(australia_df[['Country','Total Profit']])
# Out:
#                            Country  Total Profit
# 0                           Tuvalu     951410.50
# 5                  Solomon Islands     285087.64
# 19                      East Timor     337937.60
# 23                     New Zealand       5270.67
# 26                        Kiribati      13009.18
# 32                       Australia     369155.00
# 56                            Fiji     727423.20
# 60                       Australia      60418.38
# 76  Federated States of Micronesia     146875.14
# 79                          Samoa     1678540.98
# 91                       Australia     147031.74

# %%
import matplotlib.pyplot as plt
australia_df.plot(x = 'Country', y = 'Total Profit')
plt.show()
