# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaka246055/Enron-Analysis/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O enron.db https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1
# Out:
# --2025-05-04 04:29:04--  https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1
# Resolving curtin-my.sharepoint.com (curtin-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8f8::10, ...
# Connecting to curtin-my.sharepoint.com (curtin-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/211934g_curtin_edu_au/Documents/Units/ISYS2001%20ITB/ISYS2001-Assignment-2-Data/enron_sqlite3.db?ga=1 [following]
# --2025-05-04 04:29:05--  https://curtin-my.sharepoint.com/personal/211934g_curtin_edu_au/Documents/Units/ISYS2001%20ITB/ISYS2001-Assignment-2-Data/enron_sqlite3.db?ga=1
# Reusing existing connection to curtin-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 853819392 (814M) [application/octet-stream]
# Saving to: ‘enron.db’
#
# ...

# %%
#import neccessary module
import sqlite3
import time
import datetime
import random

# %%
#connect sqlite3 module with the database
conn = sqlite3.connect('enron.db')

# %%
#to load the data into the database
cur = conn.cursor()

# %%
#create employee list table
sql = """
CREATE TABLE IF NOT EXISTS users(
   Email_id TEXT PRIMARY KEY,
   eid INT
   firstName TEXT,
   lastName TEXT,
   Email2 REAL,
   Email3 REAL,
   Email4 REAL,
   folder BLOB,
   status TEXT);
"""

#Execute query and commit transaction
cur.execute(sql)
conn.commit()

# %%
#connecting the employee list and printing the tuples
rows = cur.execute("SELECT Email_id, eid, firstname, Email2, Email3, Email4,folder, status FROM employeelist").fetchall()
print(rows)
# Out:
# [('robert.badeer@enron.com', 1, 'Robert', 'rbadeer@enron.com', '', '', 'badeer-r', 'Director'), ('kevin.hyatt@enron.com', 2, 'Kevin', 'kevin_hyatt@enron.com', 'khyatt@enron.com', '', 'hyatt-k', 'Director'), ('tracy.geaccone@enron.com', 3, 'Tracy', 'tracy_geaconne@enron.com', '', '', 'geaccone-t', 'Employee'), ('teb.lokey@enron.com', 4, 'Teb', 'teb_lokey@enron.com', 'tlokey@enron.com', '', 'lokey-t', 'Manager'), ('richard.ring@enron.com', 5, 'Richard', '', '', '', 'ring-r', 'Employee'), ('mark.e.taylor@enron.com', 6, 'Mark', 'mark.taylor@enron.com', 'e.taylor@enron.com', '', 'taylor-m', 'Employee'), ('theresa.staab@enron.com', 7, 'Theresa', 'theresa_staab@enron.com', 'tstaab@enron.com', '', 'staab-t', 'Employee'), ('susan.w.pereira@enron.com', 8, 'Susan', 'w..pereira@enron.com', 'susan.peireira@enron.com', '', 'pereira-s', 'Employee'), ('stephanie.panus@enron.com', 9, 'Stephanie', '', '', '', 'panus-s', 'Employee'), ('phillip.k.ellen@enron.com', 10, 'Phillip', 'phillip.allen@enron.com
# ...

# %%
#selecting all users from the employee lis
sql = '''
SELECT * FROM employeelist;
'''

#Execute query and commit transaction  and printing the list
rows = cur.execute(sql)
for row in rows:
  print(row)
# Out:
# (1, 'Robert', 'Badeer', 'robert.badeer@enron.com', 'rbadeer@enron.com', '', '', 'badeer-r', 'Director')
# (2, 'Kevin', 'Hyatt', 'kevin.hyatt@enron.com', 'kevin_hyatt@enron.com', 'khyatt@enron.com', '', 'hyatt-k', 'Director')
# (3, 'Tracy', 'Geaccone', 'tracy.geaccone@enron.com', 'tracy_geaconne@enron.com', '', '', 'geaccone-t', 'Employee')
# (4, 'Teb', 'Lokey', 'teb.lokey@enron.com', 'teb_lokey@enron.com', 'tlokey@enron.com', '', 'lokey-t', 'Manager')
# (5, 'Richard', 'Ring', 'richard.ring@enron.com', '', '', '', 'ring-r', 'Employee')
# (6, 'Mark', 'Taylor', 'mark.e.taylor@enron.com', 'mark.taylor@enron.com', 'e.taylor@enron.com', '', 'taylor-m', 'Employee')
# (7, 'Theresa', 'Staab', 'theresa.staab@enron.com', 'theresa_staab@enron.com', 'tstaab@enron.com', '', 'staab-t', 'Employee')
# (8, 'Susan', 'Pereira', 'susan.w.pereira@enron.com', 'w..pereira@enron.com', 'susan.peireira@enron.com', '', 'pereira-s', 'Employee')
# ...

# %%
 #create a table of messages
sql = """
CREATE TABLE IF NOT EXISTS message(
   mid INT PRIMARY KEY,
   date REAL,
   subject TEXT,
   body TEXT,
   folder TEXT);
"""

#Execute query and commit transaction
cur.execute(sql)
conn.commit()

# %%
#select date and message count from the messahes dataframe
sql = '''
SELECT date(date) AS date_sent, count(mid) AS message_count
    FROM message
    GROUP BY date_sent
    ORDER BY date_sent
'''

#Execute query and commit transaction then print the data
rows = cur.execute(sql)
for row in rows:
  print(row)
# Out:
# ('0001-05-30', 2)
# ('0001-06-18', 1)
# ('0001-07-24', 1)
# ('0001-08-01', 1)
# ('0001-08-06', 1)
# ('0001-08-13', 1)
# ('0001-08-21', 1)
# ('0001-08-22', 1)
# ('0001-08-26', 1)
# ('0001-08-27', 1)
# ('0001-08-28', 4)
# ('0001-08-30', 1)
# ('0001-09-03', 1)
# ('0001-09-05', 2)
# ('0001-09-13', 1)
# ('0001-09-17', 1)
# ('0001-09-19', 1)
# ('0001-09-20', 1)
# ('0001-09-21', 1)
# ('0001-09-26', 1)
# ('0001-10-04', 1)
# ('0001-10-05', 1)
# ('0001-10-08', 1)
# ('0001-10-12', 1)
# ('0001-10-15', 3)
# ('0001-10-16', 3)
# ('0001-10-17', 4)
# ('0001-10-18', 8)
# ('0001-10-19', 1)
# ('0001-10-21', 1)
# ('0001-10-22', 6)
# ('0001-10-24', 1)
# ('0001-10-25', 4)
# ('0001-10-26', 8)
# ('0001-10-29', 18)
# ('0001-10-30', 1)
# ('0001-11-02', 1)
# ('0001-11-08', 1)
# ('0001-11-14', 1)
# ('0001-11-15', 1)
# ('0001-11-19', 10)
# ('0001-11-20', 3)
# ('0001-11-21', 7)
# ('0001-11-22', 3)
# ('0001-11-23', 1)
# ('0001-11-25', 1)
# ('0001-11-26', 9)
# ('0001-11-27', 15)
# ('0001-11-28', 2)
# ...

# %%
#import module to plot the graph of date sent against message count and print the graph
import matplotlib.pyplot as plt
message_df.plot(x = 'date_sent', y = 'message_count', figsize = (12,9))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5fa525a65624> in <cell line: 0>()
#       1 #import module to plot the graph of date sent against message count and print the graph
#       2 import matplotlib.pyplot as plt
# ----> 3 message_df.plot(x = 'date_sent', y = 'message_count', figsize = (12,9))
#       4 plt.show()
#
# NameError: name 'message_df' is not defined

# %%
#import module to plot the graph of date sent against message count and print the graph
import matplotlib.pyplot as plt
import pandas as pd # Import pandas for DataFrame creation

#select date and message count from the messahes dataframe
sql = '''
SELECT date(date) AS date_sent, count(mid) AS message_count
    FROM message
    GROUP BY date_sent
    ORDER BY date_sent
'''

# Execute query and fetch results
rows = cur.execute(sql).fetchall()

# Create a pandas DataFrame from the results
message_df = pd.DataFrame(rows, columns=['date_sent', 'message_count'])

# Now you can plot the data
message_df.plot(x = 'date_sent', y = 'message_count', figsize = (12,9))
plt.show()
